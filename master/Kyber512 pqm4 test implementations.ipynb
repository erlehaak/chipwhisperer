# %% [markdown]
# Lage pqm4

# %%
# %%sh
# cd ..
# git submodule foreach --recursive git reset --hard
# Out:
# Entering 'chipwhisperer-minimal'
# HEAD is now at 80319ec Add code
# Entering 'hardware/capture/chipwhisperer-lite/sam3u_fw/SAM3U_VendorExample/src/naeusb'
# HEAD is now at 44fcf7d Add mpsse enabled
# Entering 'hardware/capture/chipwhisperer-nano/firmware/cwnano-firmware/src/naeusb'
# HEAD is now at 44fcf7d Add mpsse enabled
# Entering 'hardware/victims/cw305_artixtarget/fw/sam3u/CW305_SAM3U_FW/src/naeusb'
# HEAD is now at 0672652 Merge branch 'main' of https://github.com/newaetech/naeusb
# Entering 'hardware/victims/firmware/crypto/Higher-Order-Masked-AES-128'
# HEAD is now at 28d8988 Add more info to readme file
# Entering 'hardware/victims/firmware/crypto/SecAESSTM32'
# HEAD is now at a209be5 Correct typo in technical-report/technical_analysis.tex: permutation permIndicesMCBis is computed from mask byte M[1] and not M[0] (idem for the key scheduling).
# Entering 'hardware/victims/firmware/crypto/masked-bit-sliced-aes-128'
# HEAD is now at 4031949 Update README.md
# Entering 'hardware/victims/firmware/crypto/secAES-ATmega8515'
# HEAD is now at 7ada843 Fix function prototype to avoid gcc complaining about it.
# Entering 'jupyter'
# HEAD is now at ce8b176 Update README.md
# Entering 'pqm4'
# HEAD is now at 1eeb74e skip aarch64 implementations when building all schemes via make
# Entering 'pqm4/libopencm3'
# HEAD is now at b1d8a4c5 stm32h7: added minimal stm32h7 exti defs, which share with G0.
# Entering 'pqm4/mupq'
# HEAD is now at 3b48fa5 skip aarch64 implementations when building all schemes via make
# Entering 'pqm4/mupq/pqclean'
# HEAD is now at 734ea31b We have not been using mergify for a very long time now.
# Entering 'pqm4/mupq/pqclean/test/pycparser'
# HEAD is now at 1166ea1 Add unaligned versions of intel vector types (#357)

# %% [markdown]
# Compile test programmer laget av pqm4:

# %%
# %%sh
# cd ../pqm4/
# make -j4 PLATFORM=cw308t-stm32f3
# Out:
#   CC      elf/\n_test.elf
#   CC      elf/\n_speed.elf
#   CC      elf/\n_hashing.elf
#   CC      elf/\n_stack.elf
# mupq/crypto_kem/test.c:1:10: fatal error: api.h: No such file or directory
#     1 | #include "api.h"
#       |          ^~~~~~~
# compilation terminated.
# mupq/crypto_kem/speed.c:1:10: fatal error: api.h: No such file or directory
#     1 | #include "api.h"
#       |          ^~~~~~~
# compilation terminated.
# mupq/crypto_kem/hashing.c:1:10: fatal error: api.h: No such file or directory
#     1 | #include "api.h"
#       |          ^~~~~~~
# compilation terminated.
# common/hal-opencm3.c: In function 'clock_setup':
# common/hal-opencm3.c:104:41: warning: unused parameter 'clock' [-Wunused-parameter]
#   104 | static void clock_setup(enum clock_mode clock)
#       |                         ~~~~~~~~~~~~~~~~^~~~~
# mupq/crypto_kem/stack.c:1:10: fatal error: api.h: No such file or directory
#     1 | #include "api.h"
#       |          ^~~~~~~
# compilation terminated.
# common/hal-opencm3.c: In function 'clock_setup':
# common/hal-opencm3.c:104:41: warning: unused parameter 'clock' [-Wunused-parameter]
#   104 | static void clock_setup(enum clock_mode clock)
#       |                         ~~~~~~~~~~~~~~~~^~~~~
# common/hal-opencm3.c: In function 'clock_setup':
# common/hal-opencm3.c:104:41: warning: unused parameter 'clock' [-Wunused-parameter]
#   104 | static void clock_setup(enum clock_mode clock)
#       |                         ~~~~~~~~~~~~~~~~^~~~~
# common/hal-opencm3.c: In function 'clock_setup':
# common/hal-opencm3.c:104:41: warning: unused parameter 'clock' [-Wunused-parameter]
#   104 | static void clock_setup(enum clock_mode clock)
#       |                         ~~~~~~~~~~~~~~~~^~~~~
# In file included from common/randombytes.c:1:
# C:/Users/erlen/ChipWhisperer5_64/cw/home/portable/chipwhisperer/pqm4/mupq/common/randombytes.h:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/randombytes.h
#       | ^
# common/randombytes.c:38:2: warning: #warning Using a non-random randombytes [-Wcpp]
#    38 | #warning Using a non-random randombytes
#       |  ^~~~~~~
# common/randombytes.c:42:8: error: unknown type name 'uint32_t'
#    42 | static uint32_t seed[32] = {3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9, 3,
#       |        ^~~~~~~~
# common/randombytes.c:44:8: error: unknown type name 'uint32_t'
#    44 | static uint32_t in[12];
#       |        ^~~~~~~~
# common/randombytes.c:45:8: error: unknown type name 'uint8_t'
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |        ^~~~~~~
# common/randombytes.c:45:31: error: 'uint32_t' undeclared here (not in a function); did you mean 'wint_t'?
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |                               ^~~~~~~~
#       |                               wint_t
# common/randombytes.c:46:8: error: unknown type name 'int32_t'
#    46 | static int32_t outleft = 0;
#       |        ^~~~~~~
# common/randombytes.c:51:18: error: expected declaration specifiers or '...' before 'uint32_t'
#    51 | static void surf(uint32_t out[8])
#       |                  ^~~~~~~~
# common/randombytes.c: In function 'randombytes_regen':
# common/randombytes.c:92:11: error: expected ';' before 'out'
#    92 |   uint32_t out[8];
#       |           ^~~~
#       |           ;
# common/randombytes.c:100:3: warning: implicit declaration of function 'surf' [-Wimplicit-function-declaration]
#   100 |   surf(out);
#       |   ^~~~
# common/randombytes.c:100:8: error: 'out' undeclared (first use in this function)
#   100 |   surf(out);
#       |        ^~~
# common/randombytes.c:100:8: note: each undeclared identifier is reported only once for each function it appears in
# common/randombytes.c: At top level:
# common/randombytes.c:114:17: error: unknown type name 'uint8_t'; did you mean 'wint_t'?
#   114 | int randombytes(uint8_t* buf, size_t xlen)
#       |                 ^~~~~~~
#       |                 wint_t
# common/randombytes.c:45:16: warning: 'out_buf' defined but not used [-Wunused-variable]
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |                ^~~~~~~
# common/randombytes.c:42:17: warning: 'seed' defined but not used [-Wunused-variable]
#    42 | static uint32_t seed[32] = {3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9, 3,
#       |                 ^~~~
# In file included from common/randombytes.c:1:
# C:/Users/erlen/ChipWhisperer5_64/cw/home/portable/chipwhisperer/pqm4/mupq/common/randombytes.h:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/randombytes.h
#       | ^
# common/randombytes.c:38:2: warning: #warning Using a non-random randombytes [-Wcpp]
#    38 | #warning Using a non-random randombytes
#       |  ^~~~~~~
# common/randombytes.c:42:8: error: unknown type name 'uint32_t'
#    42 | static uint32_t seed[32] = {3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9, 3,
#       |        ^~~~~~~~
# common/randombytes.c:44:8: error: unknown type name 'uint32_t'
#    44 | static uint32_t in[12];
#       |        ^~~~~~~~
# common/randombytes.c:45:8: error: unknown type name 'uint8_t'
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |        ^~~~~~~
# common/randombytes.c:45:31: error: 'uint32_t' undeclared here (not in a function); did you mean 'wint_t'?
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |                               ^~~~~~~~
#       |                               wint_t
# common/randombytes.c:46:8: error: unknown type name 'int32_t'
#    46 | static int32_t outleft = 0;
#       |        ^~~~~~~
# common/randombytes.c:51:18: error: expected declaration specifiers or '...' before 'uint32_t'
#    51 | static void surf(uint32_t out[8])
#       |                  ^~~~~~~~
# common/randombytes.c: In function 'randombytes_regen':
# common/randombytes.c:92:11: error: expected ';' before 'out'
#    92 |   uint32_t out[8];
#       |           ^~~~
#       |           ;
# common/randombytes.c:100:3: warning: implicit declaration of function 'surf' [-Wimplicit-function-declaration]
#   100 |   surf(out);
#       |   ^~~~
# common/randombytes.c:100:8: error: 'out' undeclared (first use in this function)
#   100 |   surf(out);
#       |        ^~~
# common/randombytes.c:100:8: note: each undeclared identifier is reported only once for each function it appears in
# common/randombytes.c: At top level:
# common/randombytes.c:114:17: error: unknown type name 'uint8_t'; did you mean 'wint_t'?
#   114 | int randombytes(uint8_t* buf, size_t xlen)
#       |                 ^~~~~~~
#       |                 wint_t
# common/randombytes.c:45:16: warning: 'out_buf' defined but not used [-Wunused-variable]
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |                ^~~~~~~
# common/randombytes.c:42:17: warning: 'seed' defined but not used [-Wunused-variable]
#    42 | static uint32_t seed[32] = {3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9, 3,
#       |                 ^~~~
# In file included from common/randombytes.c:1:
# C:/Users/erlen/ChipWhisperer5_64/cw/home/portable/chipwhisperer/pqm4/mupq/common/randombytes.h:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/randombytes.h
#       | ^
# common/randombytes.c:38:2: warning: #warning Using a non-random randombytes [-Wcpp]
#    38 | #warning Using a non-random randombytes
#       |  ^~~~~~~
# common/randombytes.c:42:8: error: unknown type name 'uint32_t'
#    42 | static uint32_t seed[32] = {3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9, 3,
#       |        ^~~~~~~~
# common/randombytes.c:44:8: error: unknown type name 'uint32_t'
#    44 | static uint32_t in[12];
#       |        ^~~~~~~~
# common/randombytes.c:45:8: error: unknown type name 'uint8_t'
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |        ^~~~~~~
# common/randombytes.c:45:31: error: 'uint32_t' undeclared here (not in a function); did you mean 'wint_t'?
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |                               ^~~~~~~~
#       |                               wint_t
# common/randombytes.c:46:8: error: unknown type name 'int32_t'
#    46 | static int32_t outleft = 0;
#       |        ^~~~~~~
# common/randombytes.c:51:18: error: expected declaration specifiers or '...' before 'uint32_t'
#    51 | static void surf(uint32_t out[8])
#       |                  ^~~~~~~~
# common/randombytes.c: In function 'randombytes_regen':
# common/randombytes.c:92:11: error: expected ';' before 'out'
#    92 |   uint32_t out[8];
#       |           ^~~~
#       |           ;
# common/randombytes.c:100:3: warning: implicit declaration of function 'surf' [-Wimplicit-function-declaration]
#   100 |   surf(out);
#       |   ^~~~
# common/randombytes.c:100:8: error: 'out' undeclared (first use in this function)
#   100 |   surf(out);
#       |        ^~~
# common/randombytes.c:100:8: note: each undeclared identifier is reported only once for each function it appears in
# common/randombytes.c: At top level:
# common/randombytes.c:114:17: error: unknown type name 'uint8_t'; did you mean 'wint_t'?
#   114 | int randombytes(uint8_t* buf, size_t xlen)
#       |                 ^~~~~~~
#       |                 wint_t
# common/randombytes.c:45:16: warning: 'out_buf' defined but not used [-Wunused-variable]
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |                ^~~~~~~
# common/randombytes.c:42:17: warning: 'seed' defined but not used [-Wunused-variable]
#    42 | static uint32_t seed[32] = {3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9, 3,
#       |                 ^~~~
# In file included from common/randombytes.c:1:
# C:/Users/erlen/ChipWhisperer5_64/cw/home/portable/chipwhisperer/pqm4/mupq/common/randombytes.h:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/randombytes.h
#       | ^
# common/randombytes.c:38:2: warning: #warning Using a non-random randombytes [-Wcpp]
#    38 | #warning Using a non-random randombytes
#       |  ^~~~~~~
# common/randombytes.c:42:8: error: unknown type name 'uint32_t'
#    42 | static uint32_t seed[32] = {3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9, 3,
#       |        ^~~~~~~~
# common/randombytes.c:44:8: error: unknown type name 'uint32_t'
#    44 | static uint32_t in[12];
#       |        ^~~~~~~~
# common/randombytes.c:45:8: error: unknown type name 'uint8_t'
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |        ^~~~~~~
# common/randombytes.c:45:31: error: 'uint32_t' undeclared here (not in a function); did you mean 'wint_t'?
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |                               ^~~~~~~~
#       |                               wint_t
# common/randombytes.c:46:8: error: unknown type name 'int32_t'
#    46 | static int32_t outleft = 0;
#       |        ^~~~~~~
# common/randombytes.c:51:18: error: expected declaration specifiers or '...' before 'uint32_t'
#    51 | static void surf(uint32_t out[8])
#       |                  ^~~~~~~~
# common/randombytes.c: In function 'randombytes_regen':
# common/randombytes.c:92:11: error: expected ';' before 'out'
#    92 |   uint32_t out[8];
#       |           ^~~~
#       |           ;
# common/randombytes.c:100:3: warning: implicit declaration of function 'surf' [-Wimplicit-function-declaration]
#   100 |   surf(out);
#       |   ^~~~
# common/randombytes.c:100:8: error: 'out' undeclared (first use in this function)
#   100 |   surf(out);
#       |        ^~~
# common/randombytes.c:100:8: note: each undeclared identifier is reported only once for each function it appears in
# common/randombytes.c: At top level:
# common/randombytes.c:114:17: error: unknown type name 'uint8_t'; did you mean 'wint_t'?
#   114 | int randombytes(uint8_t* buf, size_t xlen)
#       |                 ^~~~~~~
#       |                 wint_t
# common/randombytes.c:45:16: warning: 'out_buf' defined but not used [-Wunused-variable]
#    45 | static uint8_t out_buf[sizeof(uint32_t) * 16];
#       |                ^~~~~~~
# common/randombytes.c:42:17: warning: 'seed' defined but not used [-Wunused-variable]
#    42 | static uint32_t seed[32] = {3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9, 3,
#       |                 ^~~~
# In file included from mupq/common/sp800-185.c:6:
# mupq/common/sp800-185.h:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/sp800-185.h
#       | ^
# mupq/common/sp800-185.h:1:25: error: invalid suffix "h" on floating constant
#     1 | ../pqclean/common/sp800-185.h
#       |                         ^~~~~
# mupq/common/sp800-185.c:30:25: error: unknown type name 'shake128incctx'
#    30 | void cshake128_inc_init(shake128incctx *state, const uint8_t *name, size_t namelen, const uint8_t *cstm, size_t cstmlen) {
#       |                         ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:50:27: error: unknown type name 'shake128incctx'
#    50 | void cshake128_inc_absorb(shake128incctx *state, const uint8_t *input, size_t inlen) {
#       |                           ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:54:29: error: unknown type name 'shake128incctx'
#    54 | void cshake128_inc_finalize(shake128incctx *state) {
#       |                             ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:74:60: error: unknown type name 'shake128incctx'
#    74 | void cshake128_inc_squeeze(uint8_t *output, size_t outlen, shake128incctx *state) {
#       |                                                            ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:78:32: error: unknown type name 'shake128incctx'
#    78 | void cshake128_inc_ctx_release(shake128incctx *state) {
#       |                                ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:85:30: error: unknown type name 'shake128incctx'
#    85 | void cshake128_inc_ctx_clone(shake128incctx *dest, const shake128incctx *src) {
#       |                              ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:85:58: error: unknown type name 'shake128incctx'
#    85 | void cshake128_inc_ctx_clone(shake128incctx *dest, const shake128incctx *src) {
#       |                                                          ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:90:25: error: unknown type name 'shake256incctx'
#    90 | void cshake256_inc_init(shake256incctx *state, const uint8_t *name, size_t namelen, const uint8_t *cstm, size_t cstmlen) {
#       |                         ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:110:27: error: unknown type name 'shake256incctx'
#   110 | void cshake256_inc_absorb(shake256incctx *state, const uint8_t *input, size_t inlen) {
#       |                           ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:114:29: error: unknown type name 'shake256incctx'
#   114 | void cshake256_inc_finalize(shake256incctx *state) {
#       |                             ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:134:60: error: unknown type name 'shake256incctx'
#   134 | void cshake256_inc_squeeze(uint8_t *output, size_t outlen, shake256incctx *state) {
#       |                                                            ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c: In function 'cshake128':
# mupq/common/sp800-185.c:156:5: error: unknown type name 'shake128incctx'
#   156 |     shake128incctx state;
#       |     ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:157:5: warning: implicit declaration of function 'cshake128_inc_init' [-Wimplicit-function-declaration]
#   157 |     cshake128_inc_init(&state, name, namelen, cstm, cstmlen);
#       |     ^~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:158:5: warning: implicit declaration of function 'cshake128_inc_absorb' [-Wimplicit-function-declaration]
#   158 |     cshake128_inc_absorb(&state, input, inlen);
#       |     ^~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:159:5: warning: implicit declaration of function 'cshake128_inc_finalize' [-Wimplicit-function-declaration]
#   159 |     cshake128_inc_finalize(&state);
#       |     ^~~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:160:5: warning: implicit declaration of function 'cshake128_inc_squeeze' [-Wimplicit-function-declaration]
#   160 |     cshake128_inc_squeeze(output, outlen, &state);
#       |     ^~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c: In function 'cshake256':
# mupq/common/sp800-185.c:181:5: error: unknown type name 'shake256incctx'
#   181 |     shake256incctx state;
#       |     ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:182:5: warning: implicit declaration of function 'cshake256_inc_init' [-Wimplicit-function-declaration]
#   182 |     cshake256_inc_init(&state, name, namelen, cstm, cstmlen);
#       |     ^~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:183:5: warning: implicit declaration of function 'cshake256_inc_absorb' [-Wimplicit-function-declaration]
#   183 |     cshake256_inc_absorb(&state, input, inlen);
#       |     ^~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:184:5: warning: implicit declaration of function 'cshake256_inc_finalize' [-Wimplicit-function-declaration]
#   184 |     cshake256_inc_finalize(&state);
#       |     ^~~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:185:5: warning: implicit declaration of function 'cshake256_inc_squeeze' [-Wimplicit-function-declaration]
#   185 |     cshake256_inc_squeeze(output, outlen, &state);
#       |     ^~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c: At top level:
# mupq/common/sp800-185.c:188:32: error: unknown type name 'shake256incctx'
#   188 | void cshake256_inc_ctx_release(shake256incctx *state) {
#       |                                ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:195:30: error: unknown type name 'shake256incctx'
#   195 | void cshake256_inc_ctx_clone(shake256incctx *dest, const shake256incctx *src) {
#       |                              ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:195:58: error: unknown type name 'shake256incctx'
#   195 | void cshake256_inc_ctx_clone(shake256incctx *dest, const shake256incctx *src) {
#       |                                                          ^~~~~~~~~~~~~~
# In file included from mupq/common/sp800-185.c:6:
# mupq/common/sp800-185.h:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/sp800-185.h
#       | ^
# mupq/common/sp800-185.h:1:25: error: invalid suffix "h" on floating constant
#     1 | ../pqclean/common/sp800-185.h
#       |                         ^~~~~
# mupq/common/sp800-185.c:30:25: error: unknown type name 'shake128incctx'
#    30 | void cshake128_inc_init(shake128incctx *state, const uint8_t *name, size_t namelen, const uint8_t *cstm, size_t cstmlen) {
#       |                         ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:50:27: error: unknown type name 'shake128incctx'
#    50 | void cshake128_inc_absorb(shake128incctx *state, const uint8_t *input, size_t inlen) {
#       |                           ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:54:29: error: unknown type name 'shake128incctx'
#    54 | void cshake128_inc_finalize(shake128incctx *state) {
#       |                             ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:74:60: error: unknown type name 'shake128incctx'
#    74 | void cshake128_inc_squeeze(uint8_t *output, size_t outlen, shake128incctx *state) {
#       |                                                            ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:78:32: error: unknown type name 'shake128incctx'
#    78 | void cshake128_inc_ctx_release(shake128incctx *state) {
#       |                                ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:85:30: error: unknown type name 'shake128incctx'
#    85 | void cshake128_inc_ctx_clone(shake128incctx *dest, const shake128incctx *src) {
#       |                              ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:85:58: error: unknown type name 'shake128incctx'
#    85 | void cshake128_inc_ctx_clone(shake128incctx *dest, const shake128incctx *src) {
#       |                                                          ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:90:25: error: unknown type name 'shake256incctx'
#    90 | void cshake256_inc_init(shake256incctx *state, const uint8_t *name, size_t namelen, const uint8_t *cstm, size_t cstmlen) {
#       |                         ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:110:27: error: unknown type name 'shake256incctx'
#   110 | void cshake256_inc_absorb(shake256incctx *state, const uint8_t *input, size_t inlen) {
#       |                           ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:114:29: error: unknown type name 'shake256incctx'
#   114 | void cshake256_inc_finalize(shake256incctx *state) {
#       |                             ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:134:60: error: unknown type name 'shake256incctx'
#   134 | void cshake256_inc_squeeze(uint8_t *output, size_t outlen, shake256incctx *state) {
#       |                                                            ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c: In function 'cshake128':
# mupq/common/sp800-185.c:156:5: error: unknown type name 'shake128incctx'
#   156 |     shake128incctx state;
#       |     ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:157:5: warning: implicit declaration of function 'cshake128_inc_init' [-Wimplicit-function-declaration]
#   157 |     cshake128_inc_init(&state, name, namelen, cstm, cstmlen);
#       |     ^~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:158:5: warning: implicit declaration of function 'cshake128_inc_absorb' [-Wimplicit-function-declaration]
#   158 |     cshake128_inc_absorb(&state, input, inlen);
#       |     ^~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:159:5: warning: implicit declaration of function 'cshake128_inc_finalize' [-Wimplicit-function-declaration]
#   159 |     cshake128_inc_finalize(&state);
#       |     ^~~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:160:5: warning: implicit declaration of function 'cshake128_inc_squeeze' [-Wimplicit-function-declaration]
#   160 |     cshake128_inc_squeeze(output, outlen, &state);
#       |     ^~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c: In function 'cshake256':
# mupq/common/sp800-185.c:181:5: error: unknown type name 'shake256incctx'
#   181 |     shake256incctx state;
#       |     ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:182:5: warning: implicit declaration of function 'cshake256_inc_init' [-Wimplicit-function-declaration]
#   182 |     cshake256_inc_init(&state, name, namelen, cstm, cstmlen);
#       |     ^~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:183:5: warning: implicit declaration of function 'cshake256_inc_absorb' [-Wimplicit-function-declaration]
#   183 |     cshake256_inc_absorb(&state, input, inlen);
#       |     ^~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:184:5: warning: implicit declaration of function 'cshake256_inc_finalize' [-Wimplicit-function-declaration]
#   184 |     cshake256_inc_finalize(&state);
#       |     ^~~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:185:5: warning: implicit declaration of function 'cshake256_inc_squeeze' [-Wimplicit-function-declaration]
#   185 |     cshake256_inc_squeeze(output, outlen, &state);
#       |     ^~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c: At top level:
# mupq/common/sp800-185.c:188:32: error: unknown type name 'shake256incctx'
#   188 | void cshake256_inc_ctx_release(shake256incctx *state) {
#       |                                ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:195:30: error: unknown type name 'shake256incctx'
#   195 | void cshake256_inc_ctx_clone(shake256incctx *dest, const shake256incctx *src) {
#       |                              ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:195:58: error: unknown type name 'shake256incctx'
#   195 | void cshake256_inc_ctx_clone(shake256incctx *dest, const shake256incctx *src) {
#       |                                                          ^~~~~~~~~~~~~~
# mupq/common/nistseedexpander.c:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/nistseedexpander.c
#       | ^
# mupq/common/nistseedexpander.c:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/nistseedexpander.c
#       | ^
# In file included from mupq/common/sp800-185.c:6:
# mupq/common/sp800-185.h:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/sp800-185.h
#       | ^
# mupq/common/sp800-185.h:1:25: error: invalid suffix "h" on floating constant
#     1 | ../pqclean/common/sp800-185.h
#       |                         ^~~~~
# mupq/common/sp800-185.c:30:25: error: unknown type name 'shake128incctx'
#    30 | void cshake128_inc_init(shake128incctx *state, const uint8_t *name, size_t namelen, const uint8_t *cstm, size_t cstmlen) {
#       |                         ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:50:27: error: unknown type name 'shake128incctx'
#    50 | void cshake128_inc_absorb(shake128incctx *state, const uint8_t *input, size_t inlen) {
#       |                           ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:54:29: error: unknown type name 'shake128incctx'
#    54 | void cshake128_inc_finalize(shake128incctx *state) {
#       |                             ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:74:60: error: unknown type name 'shake128incctx'
#    74 | void cshake128_inc_squeeze(uint8_t *output, size_t outlen, shake128incctx *state) {
#       |                                                            ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:78:32: error: unknown type name 'shake128incctx'
#    78 | void cshake128_inc_ctx_release(shake128incctx *state) {
#       |                                ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:85:30: error: unknown type name 'shake128incctx'
#    85 | void cshake128_inc_ctx_clone(shake128incctx *dest, const shake128incctx *src) {
#       |                              ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:85:58: error: unknown type name 'shake128incctx'
#    85 | void cshake128_inc_ctx_clone(shake128incctx *dest, const shake128incctx *src) {
#       |                                                          ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:90:25: error: unknown type name 'shake256incctx'
#    90 | void cshake256_inc_init(shake256incctx *state, const uint8_t *name, size_t namelen, const uint8_t *cstm, size_t cstmlen) {
#       |                         ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:110:27: error: unknown type name 'shake256incctx'
#   110 | void cshake256_inc_absorb(shake256incctx *state, const uint8_t *input, size_t inlen) {
#       |                           ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:114:29: error: unknown type name 'shake256incctx'
#   114 | void cshake256_inc_finalize(shake256incctx *state) {
#       |                             ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:134:60: error: unknown type name 'shake256incctx'
#   134 | void cshake256_inc_squeeze(uint8_t *output, size_t outlen, shake256incctx *state) {
#       |                                                            ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c: In function 'cshake128':
# mupq/common/sp800-185.c:156:5: error: unknown type name 'shake128incctx'
#   156 |     shake128incctx state;
#       |     ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:157:5: warning: implicit declaration of function 'cshake128_inc_init' [-Wimplicit-function-declaration]
#   157 |     cshake128_inc_init(&state, name, namelen, cstm, cstmlen);
#       |     ^~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:158:5: warning: implicit declaration of function 'cshake128_inc_absorb' [-Wimplicit-function-declaration]
#   158 |     cshake128_inc_absorb(&state, input, inlen);
#       |     ^~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:159:5: warning: implicit declaration of function 'cshake128_inc_finalize' [-Wimplicit-function-declaration]
#   159 |     cshake128_inc_finalize(&state);
#       |     ^~~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:160:5: warning: implicit declaration of function 'cshake128_inc_squeeze' [-Wimplicit-function-declaration]
#   160 |     cshake128_inc_squeeze(output, outlen, &state);
#       |     ^~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c: In function 'cshake256':
# mupq/common/sp800-185.c:181:5: error: unknown type name 'shake256incctx'
#   181 |     shake256incctx state;
#       |     ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:182:5: warning: implicit declaration of function 'cshake256_inc_init' [-Wimplicit-function-declaration]
#   182 |     cshake256_inc_init(&state, name, namelen, cstm, cstmlen);
#       |     ^~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:183:5: warning: implicit declaration of function 'cshake256_inc_absorb' [-Wimplicit-function-declaration]
#   183 |     cshake256_inc_absorb(&state, input, inlen);
#       |     ^~~~~~~~~~~~~~~~~~~~
# In file included from mupq/common/sp800-185.c:6:
# mupq/common/sp800-185.h:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/sp800-185.h
#       | ^
# mupq/common/sp800-185.h:1:25: error: invalid suffix "h" on floating constant
#     1 | ../pqclean/common/sp800-185.h
#       |                         ^~~~~
# mupq/common/sp800-185.c:184:5: warning: implicit declaration of function 'cshake256_inc_finalize' [-Wimplicit-function-declaration]
#   184 |     cshake256_inc_finalize(&state);
#       |     ^~~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:185:5: warning: implicit declaration of function 'cshake256_inc_squeeze' [-Wimplicit-function-declaration]
#   185 |     cshake256_inc_squeeze(output, outlen, &state);
#       |     ^~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c: At top level:
# mupq/common/sp800-185.c:188:32: error: unknown type name 'shake256incctx'
#   188 | void cshake256_inc_ctx_release(shake256incctx *state) {
#       |                                ^~~~~~~~~~~~~~
# In file included from mupq/common/hal.h:5,
#                  from mupq/common/sp800-185.c:9:
# c:\users\erlen\chipwh~1\cw\home\portable\armgcc\arm-none-eabi\include\stdlib.h:92:1: error: unknown type name 'div_t'; did you mean 'ldiv_t'?
#    92 | div_t div (int __numer, int __denom);
#       | ^~~~~
#       | ldiv_t
# mupq/common/sp800-185.c:195:30: error: unknown type name 'shake256incctx'
#   195 | void cshake256_inc_ctx_clone(shake256incctx *dest, const shake256incctx *src) {
#       |                              ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:195:58: error: unknown type name 'shake256incctx'
#   195 | void cshake256_inc_ctx_clone(shake256incctx *dest, const shake256incctx *src) {
#       |                                                          ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:30:25: error: unknown type name 'shake128incctx'
#    30 | void cshake128_inc_init(shake128incctx *state, const uint8_t *name, size_t namelen, const uint8_t *cstm, size_t cstmlen) {
#       |                         ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:50:27: error: unknown type name 'shake128incctx'
#    50 | void cshake128_inc_absorb(shake128incctx *state, const uint8_t *input, size_t inlen) {
#       |                           ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:54:29: error: unknown type name 'shake128incctx'
#    54 | void cshake128_inc_finalize(shake128incctx *state) {
#       |                             ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:74:60: error: unknown type name 'shake128incctx'
#    74 | void cshake128_inc_squeeze(uint8_t *output, size_t outlen, shake128incctx *state) {
#       |                                                            ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:78:32: error: unknown type name 'shake128incctx'
#    78 | void cshake128_inc_ctx_release(shake128incctx *state) {
#       |                                ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:85:30: error: unknown type name 'shake128incctx'
#    85 | void cshake128_inc_ctx_clone(shake128incctx *dest, const shake128incctx *src) {
#       |                              ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:85:58: error: unknown type name 'shake128incctx'
#    85 | void cshake128_inc_ctx_clone(shake128incctx *dest, const shake128incctx *src) {
#       |                                                          ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:90:25: error: unknown type name 'shake256incctx'
#    90 | void cshake256_inc_init(shake256incctx *state, const uint8_t *name, size_t namelen, const uint8_t *cstm, size_t cstmlen) {
#       |                         ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:110:27: error: unknown type name 'shake256incctx'
#   110 | void cshake256_inc_absorb(shake256incctx *state, const uint8_t *input, size_t inlen) {
#       |                           ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:114:29: error: unknown type name 'shake256incctx'
#   114 | void cshake256_inc_finalize(shake256incctx *state) {
#       |                             ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:134:60: error: unknown type name 'shake256incctx'
#   134 | void cshake256_inc_squeeze(uint8_t *output, size_t outlen, shake256incctx *state) {
#       |                                                            ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c: In function 'cshake128':
# mupq/common/sp800-185.c:156:5: error: unknown type name 'shake128incctx'
#   156 |     shake128incctx state;
#       |     ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:157:5: warning: implicit declaration of function 'cshake128_inc_init' [-Wimplicit-function-declaration]
#   157 |     cshake128_inc_init(&state, name, namelen, cstm, cstmlen);
#       |     ^~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:158:5: warning: implicit declaration of function 'cshake128_inc_absorb' [-Wimplicit-function-declaration]
#   158 |     cshake128_inc_absorb(&state, input, inlen);
#       |     ^~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:159:5: warning: implicit declaration of function 'cshake128_inc_finalize' [-Wimplicit-function-declaration]
#   159 |     cshake128_inc_finalize(&state);
#       |     ^~~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:160:5: warning: implicit declaration of function 'cshake128_inc_squeeze' [-Wimplicit-function-declaration]
#   160 |     cshake128_inc_squeeze(output, outlen, &state);
#       |     ^~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c: In function 'cshake256':
# mupq/common/sp800-185.c:181:5: error: unknown type name 'shake256incctx'
#   181 |     shake256incctx state;
#       |     ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:182:5: warning: implicit declaration of function 'cshake256_inc_init' [-Wimplicit-function-declaration]
#   182 |     cshake256_inc_init(&state, name, namelen, cstm, cstmlen);
#       |     ^~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:183:5: warning: implicit declaration of function 'cshake256_inc_absorb' [-Wimplicit-function-declaration]
#   183 |     cshake256_inc_absorb(&state, input, inlen);
#       |     ^~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:184:5: warning: implicit declaration of function 'cshake256_inc_finalize' [-Wimplicit-function-declaration]
#   184 |     cshake256_inc_finalize(&state);
#       |     ^~~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c:185:5: warning: implicit declaration of function 'cshake256_inc_squeeze' [-Wimplicit-function-declaration]
#   185 |     cshake256_inc_squeeze(output, outlen, &state);
#       |     ^~~~~~~~~~~~~~~~~~~~~
# mupq/common/sp800-185.c: At top level:
# mupq/common/sp800-185.c:188:32: error: unknown type name 'shake256incctx'
#   188 | void cshake256_inc_ctx_release(shake256incctx *state) {
#       |                                ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:195:30: error: unknown type name 'shake256incctx'
#   195 | void cshake256_inc_ctx_clone(shake256incctx *dest, const shake256incctx *src) {
#       |                              ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:195:58: error: unknown type name 'shake256incctx'
#   195 | void cshake256_inc_ctx_clone(shake256incctx *dest, const shake256incctx *src) {
#       |                                                          ^~~~~~~~~~~~~~
# mupq/common/sp800-185.c:13:15: warning: 'left_encode' defined but not used [-Wunused-function]
#    13 | static size_t left_encode(uint8_t *encbuf, uint64_t value) {
#       |               ^~~~~~~~~~~
# mupq/common/nistseedexpander.c:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/nistseedexpander.c
#       | ^
# mupq/common/nistseedexpander.c:1:1: error: expected identifier or '(' before '.' token
#     1 | ../pqclean/common/nistseedexpander.c
#       | ^
# make: *** [mupq/mk/schemes.mk:136: elf/\n_test.elf] Error 1
# make: *** Waiting for unfinished jobs....
# make: *** [mupq/mk/schemes.mk:136: elf/\n_speed.elf] Error 1
# make: *** [mupq/mk/schemes.mk:136: elf/\n_stack.elf] Error 1
# make: *** [mupq/mk/schemes.mk:136: elf/\n_hashing.elf] Error 1
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_ipython().run_cell_magic('sh', '', 'cd ../pqm4/\nmake -j4 PLATFORM=cw308t-stm32f3\n')
#
# File ~\CHIPWH~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\IPython\core\interactiveshell.py:2422, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2420 with self.builtin_trap:
#    2421     args = (magic_arg_s, cell)
# -> 2422     result = fn(*args, **kwargs)
#    2423 return result
#
# File ~\CHIPWH~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\IPython\core\magics\script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~\CHIPWH~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\IPython\core\magics\script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'cd ../pqm4/\nmake -j4 PLATFORM=cw308t-stm32f3\n'' returned non-zero exit status 2.

# %%
# %%sh
# cd ../pqm4/
# python test.py kyber512 -p cw308t-stm32f3
# Out:
# (ChipWhisperer Other WARNING|File __init__.py:69) ChipWhisperer update available! See https://chipwhisperer.readthedocs.io/en/latest/installing.html for updating instructions
# Traceback (most recent call last):
#   File "C:\Users\erlen\ChipWhisperer5_64\cw\home\portable\chipwhisperer\pqm4\test.py", line 12, in <module>
#     test.test_all(rest)
#   File "C:\Users\erlen\ChipWhisperer5_64\cw\home\portable\chipwhisperer\pqm4\mupq\mupq.py", line 197, in test_all
#     for implementation in self.get_implementations():
#   File "C:\Users\erlen\ChipWhisperer5_64\cw\home\portable\chipwhisperer\pqm4\mupq\mupq.py", line 128, in get_implementations
#     impl = Implementation.from_path(parent, path, namespace, self.makeflags)
#   File "C:\Users\erlen\ChipWhisperer5_64\cw\home\portable\chipwhisperer\pqm4\mupq\mupq.py", line 53, in from_path
#     raise Exception(f"Unexpected path format: '{path}'")
# Exception: Unexpected path format: 'crypto_kem\bikel1\m4f'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_cell_magic('sh', '', 'cd ../pqm4/\npython test.py kyber512 -p cw308t-stm32f3\n')
#
# File ~\CHIPWH~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\IPython\core\interactiveshell.py:2422, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2420 with self.builtin_trap:
#    2421     args = (magic_arg_s, cell)
# -> 2422     result = fn(*args, **kwargs)
#    2423 return result
#
# File ~\CHIPWH~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\IPython\core\magics\script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~\CHIPWH~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\IPython\core\magics\script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'cd ../pqm4/\npython test.py kyber512 -p cw308t-stm32f3\n'' returned non-zero exit status 1.
